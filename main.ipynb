# %%
import Portfolio_monte

# %%
Portfolio_monte.get_w()
# Out:
# ----------------------------------------------------
# Choose your way:
# A: select random n stocks
# B: give the stock list
# 5
# ----------------------------------------------------
# Wrong value!
# ----------------------------------------------------
# Choose your way:
# A: select random n stocks
# B: give the stock list
# A
# ----------------------------------------------------
# How many stocks do you want to buy?(input an integer)5
# ----------------------------------------------------
# The stock portfolio is:  ['300219.SZ' '300128.SZ' '300179.SZ' '600636.SH' '601311.SH']
# ----------------------------------------------------
# The best weight for portfolio is:  [0.49725555 0.00584734 0.27298074 0.00130141 0.22261496]
# ----------------------------------------------------
# The cumulative return of portfolio:

# %%
"002379.SZ","600817.SH","600385.SH"
# Out:
# ('002379.SZ', '600817.SH', '600385.SH')

# %%
Portfolio_monte.get_w()
# Out:
# ----------------------------------------------------
# Choose your way:
# A: select random n stocks
# B: give the stock list
# B
# ----------------------------------------------------
# Which stocks do you want to buy(put stock code one by one end with nothing):
#
# 002379.SZ
# 600817.SH
# 600385.SH
#
# ----------------------------------------------------
# The best weight for portfolio is:  [0.00172963 0.67718477 0.3210856 ]
# ----------------------------------------------------
# The cumulative return of portfolio:

# %%
Portfolio_monte.data
# Out:
#       index    ts_code  symbol     name area industry list_date
# 0         0  000001.SZ  000001     平安银行   深圳       银行  19910403
# 1         1  000002.SZ  000002      万科A   深圳     全国地产  19910129
# 2         2  000004.SZ  000004     ST国华   深圳     软件服务  19910114
# 3         3  000005.SZ  000005     ST星源   深圳     环境保护  19901210
# 4         4  000006.SZ  000006     深振业A   深圳     区域地产  19920427
# ...     ...        ...     ...      ...  ...      ...       ...
# 4709   4721  688799.SH  688799     华纳药厂   湖南     化学制药  20210713
# 4710   4722  688800.SH  688800      瑞可达   江苏      元器件  20210722
# 4711   4723  688819.SH  688819     天能股份   浙江     电气设备  20210118
# 4712   4724  688981.SH  688981     中芯国际   上海      半导体  20200716
# 4713   4810  689009.SH  689009  九号公司-WD   北京      摩托车  20201029
#
# [4714 rows x 7 columns]
